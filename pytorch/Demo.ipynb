# %%
import torch;

print("hello world!");

# pytorch 的 Tensor 类型
a = torch.FloatTensor(2, 3);
a = torch.rand(2, 3);
b = torch.IntTensor([2, 3, 4, 5]);
print(a);
print(b);
# Out:
# hello world!
# tensor([[0.4200, 0.2581, 0.4484],
#         [0.6462, 0.1596, 0.3031]])
# tensor([2, 3, 4, 5], dtype=torch.int32)
